# %% [markdown]
# Business Logic 💳 :
# -
#
#         Who is the system for? ( Specific Person ) / Not General
#
#         What is the values of our project? :
#
#             - What will the user got back from using?👥
#             - Scalability, Adaptability or Ensure📈
#
#         Is it legal for law?
#
#         System Required Smart Contract?:
#
#             - Verification, Security, Data Protection🪬
#             - Where can the user trust us?
#             - Legal Contract : How strong is the Algorithms ( clear?, fair?, or enforceable )
#             - How do we know if smart contract can be used

# %% [markdown]
# Build Required Business Logic First 📜:
# -
# - Research Business/Workflow
# - Need 30 => 40% of data for testing

# %%
# Example

#= Build DataSchema =#

peoples = [
    {
        "name": "David",
        "age": 20,
        "credit_card": "29745hdahwe21399462198hdsjdhawhe209132",
        "transaction": [
            {
                "order":  "donut",
                "price": 10
            },
            {
                "order":  "donut",
                "price": 10
            }
            ]
    },
]

# %% [markdown]
# Build A Business Roadmap🗺️📍:
# -
#
# - How to project work :
#     - Usable, Easy to follow
#     - Editability
#
#     💵 Money
#
#     Revenue :
#
#         - Where is the money flow?
#         - Subscription?, Register fee, lisence?
#     Cost :
#
#         - Marketing
#         - Infrastructure required to Deployed
#
#     StakeHolder :
#
#         - Who can collaborate with us?
#         - Investor.. Who?
#         - Lawer, Developer, Regulator
#         - Alignment : Make sure they had a reason to support ? value?
#     Permission for User to Use :
#
#         - Setting permission
#         - Admin
#         - Editor
#         - User

# %% [markdown]
# Risk Management 📉:
# -
# - Financial Risk
# - Algorithms Risk
# - Legal Status ( Review with Partnership/Past Expirence )
# - Blockchain developer required to work with lawer & Gov
# - Before started to code we can read the requirement for the law
# - Consequence would fall into developer, user or stakeholder

# %% [markdown]
# Education📲🤓 :
# -
#
# - Know the code and Algorithms
# - Does it have bugs
# - Go through many phrases of testing
# - Keywords, Does stakeholder agree

# %% [markdown]
# Interactual Property 🚥:
# -
# - Brand
# - Design
# - Content
# - UX/UI
# - Sponsored
# - Naming
# - Comparison
# - Trademark
# - Personal Data Privacy Protection Law

# %% [markdown]
# Comsumer Protextion Law ⚖️:
# -
# - Protecting user from online scam
# - Honest competitor
# - Transparency with User
# - See Potential Risk

# %% [markdown]
# Immutability 🐦‍🔥 :
# -
# - Cannot create new regarless
# - Cannot update
# - Cannot delete
#
#     - Noted Tip🥴 :
#         1. Design " Smart Contract " as efficient as possible
#         2. Require Professional, Stakeholder to communicated Requirement
#         3. Organization must know how centralized & decentralize before set role & required balance with stake holder that use the appication

# %% [markdown]
# Jurisdition in Distributed Ledger System 🪢:
# -
# - Required to store data in the Admin Nodes
# - Can the user trust the System
# - Code cannot be channge but Law are require
# - Update Code integrate API contently
# - Communication more with official coin offering
# - Cambodia continue to build technology Framework
#
# Case Studies :
# - Singapore use profession Digital Law model.
# - UK have test their FinTech & Blockchain firm Before Release.
# - Cross Border Transfer & Inovation to protect user benefit
# - Build trust with starups and regulators
# - Gov can studies their latest technology

# %% [markdown]
# Entreprise Blockchain Govement Models Feature  ( eg Hyperledger ):
# -
#
# - Developer must create Role & Permission
# - Used Linux open source
